# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

import warnings

# ignoring all warning messages
warnings.simplefilter('ignore')

# %% [markdown]
# ### Problem Statement: Parkinson's disease is a progressive disorder that affects the nervous system and the parts of the body controlled by the nerves. My goal for this project is to find a model that can predict Parkinson's disease in a patient to the highest degree of accuracy based on features derived from vocal recordings, which could then be possibly used as an additional screening tool in a hospital or examination room setting.

# %%
df = pd.read_csv('../Data/parkinsons.data')

# %%
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
df.shape
# Out:
# (195, 24)

# %%
df.name.nunique()
# Out:
# 195

# %% [markdown]
# ### Cleaning: I will be checking for null values, feature data types, and duplicate rows to see if anything needs to be changed, dropped, or imputed.

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
df.dtypes
# Out:
# name                 object
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
df.duplicated().any()
# Out:
# False

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %% [markdown]
# ## Baseline to beat for classification purposes is 75.38%

# %%
df.status.value_counts(normalize=True)
# Out:
# 1    0.753846
# 0    0.246154
# Name: status, dtype: float64

# %%
df.shape
# Out:
# (195, 24)

# %%
# Creating a function to for distribution plots and highlightighting highest value

def distplot(feature):
    sns.set(rc={'figure.figsize':(11.7,8.27)})
    ax = sns.distplot(df[feature])

    heights = [x.get_height() for x in ax.patches]
    for bar in ax.patches:
        if bar.get_height() == max(heights):
            bar.set_color('blue')
        else:
            bar.set_color('red')
    plt.title(f'{feature} Distribution', fontsize=20)
    ;

# %%
# creating a quick boxplot to check for outliers 

def boxplot(column):
    ax = sns.boxplot(x=df[column])
    plt.title(f'{column} Boxplot', fontsize=20)

# %% [markdown]
# ### I will be checking the distribution of all features as well as checking for any outliers using boxplots. I will also include a small dataframe of what status those particular outliers belong to in order to see any trends. After all of the charts I will give a brief explanation of my findings below.

# %%
distplot('MDVP:Fo(Hz)')

# %%
boxplot('MDVP:Fo(Hz)')

# %%
X = df.drop('name', axis=1)

# %%
distplot('MDVP:Fhi(Hz)')

# %%
boxplot('MDVP:Fhi(Hz)')

# %%
df[df['MDVP:Fhi(Hz)'] > 390][['status', 'MDVP:Fhi(Hz)']]
# Out:
#      status  MDVP:Fhi(Hz)
# 73        1       588.518
# 102       1       586.567
# 115       1       492.892
# 116       1       442.557
# 117       1       450.247
# 118       1       442.824
# 120       1       479.697
# 149       1       565.740
# 186       0       592.030
# 187       0       581.289
# 193       0       396.961

# %%
distplot('MDVP:Flo(Hz)')

# %%
boxplot('MDVP:Flo(Hz)')

# %%
df[df['MDVP:Flo(Hz)'] > 220][['status', 'MDVP:Flo(Hz)']]
# Out:
#      status  MDVP:Flo(Hz)
# 42        0       225.227
# 43        0       232.483
# 44        0       232.435
# 45        0       227.911
# 46        0       231.848
# 63        0       223.634
# 64        0       221.156
# 166       0       229.256
# 167       0       237.303
# 170       0       239.170

# %%
distplot('MDVP:Jitter(%)')

# %%
boxplot('MDVP:Jitter(%)')

# %%
df[df['MDVP:Jitter(%)'] > .015][['status', 'MDVP:Jitter(%)']]
# Out:
#      status  MDVP:Jitter(%)
# 99        1         0.01936
# 100       1         0.03316
# 101       1         0.01551
# 102       1         0.03011
# 146       1         0.01568
# 148       1         0.01719
# 149       1         0.01627
# 150       1         0.01872
# 151       1         0.03107
# 152       1         0.02714
# 157       1         0.01813

# %%
distplot('MDVP:Jitter(Abs)')

# %%
boxplot('MDVP:Jitter(Abs)')

# %%
df[df['MDVP:Jitter(Abs)'] > .00013][['status', 'MDVP:Jitter(Abs)']]
# Out:
#      status  MDVP:Jitter(Abs)
# 99        1           0.00015
# 100       1           0.00026
# 102       1           0.00022
# 151       1           0.00016
# 152       1           0.00014
# 157       1           0.00015

# %%
distplot('MDVP:RAP')

# %%
boxplot('MDVP:RAP')

# %%
df[df['MDVP:RAP'] > .008][['status', 'MDVP:RAP']]
# Out:
#      status  MDVP:RAP
# 98        1   0.00826
# 99        1   0.01159
# 100       1   0.02144
# 101       1   0.00905
# 102       1   0.01854
# 146       1   0.00863
# 147       1   0.00849
# 148       1   0.00996
# 149       1   0.00919
# 150       1   0.01075
# 151       1   0.01800
# 152       1   0.01568
# 157       1   0.01117

# %%
distplot('MDVP:PPQ')

# %%
boxplot('MDVP:PPQ')

# %%
df[df['MDVP:PPQ'] > 0.0075][['status', 'MDVP:PPQ']]
# Out:
#      status  MDVP:PPQ
# 2         1   0.00781
# 4         1   0.00908
# 99        1   0.00990
# 100       1   0.01522
# 101       1   0.00909
# 102       1   0.01628
# 146       1   0.00946
# 147       1   0.00819
# 148       1   0.01027
# 149       1   0.00963
# 150       1   0.01154
# 151       1   0.01958
# 152       1   0.01699

# %%
distplot('Jitter:DDP')

# %%
boxplot('Jitter:DDP')

# %%
df[df['Jitter:DDP'] > .02][['status', 'Jitter:DDP']]
# Out:
#      status  Jitter:DDP
# 97        1     0.02228
# 98        1     0.02478
# 99        1     0.03476
# 100       1     0.06433
# 101       1     0.02716
# 102       1     0.05563
# 146       1     0.02589
# 147       1     0.02546
# 148       1     0.02987
# 149       1     0.02756
# 150       1     0.03225
# 151       1     0.05401
# 152       1     0.04705
# 157       1     0.03351

# %%
distplot('MDVP:Shimmer')

# %%
boxplot('MDVP:Shimmer')

# %%
df[df['MDVP:Shimmer'] > .07][['status', 'MDVP:Shimmer']]
# Out:
#      status  MDVP:Shimmer
# 91        1       0.07959
# 100       1       0.09178
# 102       1       0.09419
# 146       1       0.08143
# 148       1       0.07118
# 149       1       0.07170
# 151       1       0.11908
# 152       1       0.08684

# %%
distplot('MDVP:Shimmer(dB)')

# %%
df[df['MDVP:Shimmer(dB)'] > 0.9][['status', 'MDVP:Shimmer(dB)']]
# Out:
#      status  MDVP:Shimmer(dB)
# 102       1             0.930
# 151       1             1.302
# 152       1             1.018

# %%
distplot('Shimmer:APQ3')

# %%
df[df['Shimmer:APQ3'] > 0.05][['status', 'Shimmer:APQ3']]
# Out:
#      status  Shimmer:APQ3
# 100       1       0.05358
# 102       1       0.05551
# 151       1       0.05647

# %%
distplot('Shimmer:APQ5')

# %%
boxplot('Shimmer:APQ5')

# %%
df[df['Shimmer:APQ5'] > 0.045][['status', 'Shimmer:APQ5']]
# Out:
#      status  Shimmer:APQ5
# 1         1       0.04518
# 4         1       0.04825
# 91        1       0.04962
# 100       1       0.04791
# 102       1       0.05005
# 146       1       0.05426
# 148       1       0.04580
# 151       1       0.07940
# 152       1       0.05556

# %%
distplot('MDVP:APQ')

# %%
boxplot('MDVP:APQ')

# %%
df[df['MDVP:APQ'] > 0.055][['status', 'MDVP:APQ']]
# Out:
#      status  MDVP:APQ
# 18        1   0.05767
# 91        1   0.05690
# 99        1   0.05783
# 100       1   0.06196
# 102       1   0.06023
# 146       1   0.08808
# 147       1   0.06359
# 148       1   0.06824
# 149       1   0.06460
# 150       1   0.06259
# 151       1   0.13778
# 152       1   0.08318

# %%
distplot('Shimmer:DDA')

# %%
boxplot('Shimmer:DDA')

# %%
df[df['Shimmer:DDA'] > .12][['status', 'Shimmer:DDA']]
# Out:
#      status  Shimmer:DDA
# 91        1      0.13262
# 100       1      0.16074
# 102       1      0.16654
# 141       1      0.12047
# 151       1      0.16942
# 152       1      0.12851

# %%
distplot('NHR')

# %%
boxplot('NHR')

# %%
df[df['NHR'] > 0.08][['status', 'NHR']]
# Out:
#      status      NHR
# 90        1  0.08725
# 97        1  0.08151
# 98        1  0.10323
# 99        1  0.16744
# 100       1  0.31482
# 101       1  0.11843
# 102       1  0.25930
# 148       1  0.08069
# 150       1  0.10952
# 151       1  0.21713
# 152       1  0.16265
# 157       1  0.10748
# 192       0  0.10715

# %%
distplot('RPDE')

# %%
boxplot('RPDE')

# %%
distplot('DFA')

# %%
boxplot('DFA')

# %%
distplot('spread1')

# %%
boxplot('spread1')

# %%
distplot('spread2')

# %%
boxplot('spread2')

# %%
distplot('D2')

# %%
boxplot('D2')

# %%
distplot('PPE')

# %%
boxplot('PPE')

# %%
df[df['PPE'] > 0.41][['status', 'PPE']]
# Out:
#      status       PPE
# 4         1  0.410335
# 17        1  0.430788
# 102       1  0.444774
# 146       1  0.457533
# 148       1  0.418646
# 151       1  0.527367
# 152       1  0.454721

# %% [markdown]
# ## After looking at each individual feature for distribution and outliers, it appears that the majority of all outliers are attributed to people who have Parkinson's disease. I will choose to keep outliers as they may be indicative traits of the disease I am attempting to predict on. I will choose a model that does not assume a normal distribution for classification purposes.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### I want to compare some descriptive statistics on people who are sick vs people who are healthy

# %%
df[df['status'] == 1].describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   147.000000    147.000000    147.000000      147.000000
# mean    145.180762    188.441463    106.893558        0.006989
# std      32.348050     88.339180     32.274358        0.005240
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    133.776500     80.875500        0.004005
# 50%     145.174000    163.335000     99.770000        0.005440
# 75%     170.071000    207.160500    129.240000        0.007670
# max     223.361000    588.518000    199.020000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        147.000000  147.000000  147.000000  147.000000    147.000000
# mean           0.000051    0.003757    0.003900    0.011273      0.033658
# std            0.000037    0.003241    0.002998    0.009724      0.019970
# min            0.000010    0.000680    0.000920    0.002040      0.010220
# ...

# %%
df[df['status'] == 0].describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count    48.000000     48.000000     48.000000       48.000000
# mean    181.937771    223.636750    145.207292        0.003866
# std      52.731067     96.727067     58.757070        0.002055
# min     110.739000    113.597000     74.287000        0.001780
# 25%     120.947500    139.413250     98.243750        0.002655
# 50%     198.996000    231.161500    113.938500        0.003355
# 75%     229.077000    251.239250    199.183000        0.004530
# max     260.105000    592.030000    239.170000        0.013600
#
#        MDVP:Jitter(Abs)   MDVP:RAP   MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count         48.000000  48.000000  48.000000   48.000000     48.000000
# mean           0.000023   0.001925   0.002056    0.005776      0.017615
# std            0.000015   0.001066   0.000943    0.003199      0.005544
# min            0.000007   0.000920   0.001060    0.002760      0.009540
# ...

# %%
healthy = df[df['status'] == 0]
sick = df[df['status'] == 1]

# %%
Healthy_vs_Sick = pd.DataFrame([healthy.mean(), sick.mean()])
Healthy_vs_Sick.index = ['healthy', 'sick']
Healthy_vs_Sick
# Out:
#          MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# healthy   181.937771    223.636750    145.207292        0.003866
# sick      145.180762    188.441463    106.893558        0.006989
#
#          MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# healthy          0.000023  0.001925  0.002056    0.005776      0.017615
# sick             0.000051  0.003757  0.003900    0.011273      0.033658
#
#          MDVP:Shimmer(dB)  ...  Shimmer:DDA       NHR        HNR  status  \
# healthy          0.162958  ...     0.028511  0.011483  24.678750     0.0
# sick             0.321204  ...     0.053027  0.029211  20.974048     1.0
#
#              RPDE       DFA   spread1   spread2        D2       PPE
# healthy  0.442552  0.695716 -6.759264  0.160292  2.154491  0.123017
# sick     0.516816  0.725408 -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 23 columns]

# %% [markdown]
# ### After comparing some stats, it looks like there is quite a difference on some mean feature values between sick and healthy patients, with this information I will plot some comparisons below for easy viewing.

# %%
labels = ['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)']
healthy1 = healthy[['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)']].mean()
sick1 = sick[['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)']].mean()

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars


fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, healthy1, width, label='Healthy')
rects2 = ax.bar(x + width/2, sick1, width, label='Sick')


ax.set_ylabel('Hertz')
ax.set_title('Average Sick vs Healthy MDVP features in Hertz\n',
                 fontsize=18, 
                 fontweight='bold', 
                 color='Black')

ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3, fmt='%.2f')
ax.bar_label(rects2, padding=3, fmt='%.2f')

# plt.figure(figsize=(20, 15)

# plt.figure(figsize=(20,12))
fig.tight_layout()


plt.show()

# %% [markdown]
# ### We can see a generally lower frequency in patients that are sick vs ones that are not

# %%
labels = ['Shimmer:APQ3', 'Shimmer:APQ5', 'Shimmer:DDA', 'MDVP:Shimmer', 'MDVP:APQ']
healthy1 = 100*healthy[['Shimmer:APQ3', 'Shimmer:APQ5', 'Shimmer:DDA', 'MDVP:Shimmer', 'MDVP:APQ']].mean()
sick1 = 100*sick[['Shimmer:APQ3', 'Shimmer:APQ5', 'Shimmer:DDA', 'MDVP:Shimmer', 'MDVP:APQ']].mean()

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars


fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, healthy1, width, label='Healthy')
rects2 = ax.bar(x + width/2, sick1, width, label='Sick')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Amplitude')

ax.set_title('Average Sick vs Healthy Variations of Amplitude, x100\n',
                 fontsize=18, 
                 fontweight='bold', 
                 color='Black')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3, fmt='%.2f')
ax.bar_label(rects2, padding=3, fmt='%.2f')

# plt.figure(figsize=(20, 15)

# plt.figure(figsize=(20,12))
fig.tight_layout()


plt.show()

# %% [markdown]
# ### In the above chart we can see that Sick patients have much higher variations of amplitude compared to their healthy counterparts

# %%
labels = ['MDVP:Shimmer(dB)']
healthy1 = 100*healthy['MDVP:Shimmer(dB)'].mean()
sick1 = 100*sick['MDVP:Shimmer(dB)'].mean()

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars


fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, healthy1, width, label='Healthy')
rects2 = ax.bar(x + width/2, sick1, width, label='Sick')


ax.set_ylabel('Shimmer in dB')

ax.set_title('Average Sick vs Healthy Shimmer dB, x100\n',
                 fontsize=18, 
                 fontweight='bold', 
                 color='Black')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3, fmt='%.2f')
ax.bar_label(rects2, padding=3, fmt='%.2f')

# plt.figure(figsize=(20, 15)

# plt.figure(figsize=(20,12))
fig.tight_layout()


plt.show()

# %% [markdown]
# ### Again, the above chart shows a vast difference in sick vs health patients.

# %%
labels = ['MDVP:Jitter(%)']
healthy1 = 1000*healthy['MDVP:Jitter(%)'].mean()
sick1 = 1000*sick['MDVP:Jitter(%)'].mean()

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars


fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, healthy1, width, label='Healthy')
rects2 = ax.bar(x + width/2, sick1, width, label='Sick')


ax.set_ylabel('Percentage')

ax.set_title('Average Sick vs Healthy Average Jitter %, x1000\n',
                 fontsize=18, 
                 fontweight='bold', 
                 color='Black')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3, fmt='%.2f')
ax.bar_label(rects2, padding=3, fmt='%.2f')

# plt.figure(figsize=(20, 15)

# plt.figure(figsize=(20,12))
fig.tight_layout()


plt.show()

# %% [markdown]
# ### Sick patients also have almost double the jitter percentage in their voice compared to healthy patients

# %% [markdown]
# ----------------
# ----------------

# %% [markdown]
# ## Cleaning and EDA summary:
#
# - Null values, data types, and duplicates were checked. None needed to be changed.
#
#
# - Outliers were checked for all features. Although there were some within the dataset, most of them belonged to people who exhibited the disease. If I were to drop these outliers, given the small dataset, I could be removing traits of the disease as well as a removing a significant percentage of the dataset. I will thus choose a model that is robust to outliers to get accurate results.
#
#
# - I see there is definitely clear evidence that there is significant differences in average values between a healthy patient and one who has Parkinson's disease based on vocal features. With this quick overview I feel I will be able to build a model that will distinguish classes with a good degree of accuracy.

# %% [markdown]
# To --> [02_preprocessing](./02_preprocessing.ipynb) notebook
